# %%
from rocketry import Rocketry
import schedule
import time

# %%
def do_noting():
    print('Sujit Shibaprasad Maity')

# %%
schedule.every(5).seconds.do(do_noting)
# Out:
# Every 5 seconds do do_noting() (last run: [never], next run: 2023-04-04 13:41:22)

# %%
while True:
    schedule.run_pending()
    time.sleep(2)
# Out:
# Sujit Shibaprasad Maity
# Sujit Shibaprasad Maity
# Sujit Shibaprasad Maity
# Sujit Shibaprasad Maity
# Sujit Shibaprasad Maity
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14360\4244418335.py in <module>
#       1 while True:
#       2     schedule.run_pending()
# ----> 3     time.sleep(2)
#
# KeyboardInterrupt:
